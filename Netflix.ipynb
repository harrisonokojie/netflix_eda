# %% [markdown]
# <a href="https://colab.research.google.com/github/harrisonokojie/netflix_eda/blob/main/Netflix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
netflix = pd.read_csv('/content/Dataset/netflix_titles.csv')

# %% [markdown]
# **LOADING THE FIRST 12 ROWS**

# %%
netflix.head(12)
# Out:
#    show_id     type                                title  \
# 0       s1    Movie                 Dick Johnson Is Dead
# 1       s2  TV Show                        Blood & Water
# 2       s3  TV Show                            Ganglands
# 3       s4  TV Show                Jailbirds New Orleans
# 4       s5  TV Show                         Kota Factory
# 5       s6  TV Show                        Midnight Mass
# 6       s7    Movie     My Little Pony: A New Generation
# 7       s8    Movie                              Sankofa
# 8       s9  TV Show        The Great British Baking Show
# 9      s10    Movie                         The Starling
# 10     s11  TV Show  Vendetta: Truth, Lies and The Mafia
# 11     s12  TV Show                     Bangkok Breaking
#
#                          director  \
# 0                 Kirsten Johnson
# 1                             NaN
# 2                 Julien Leclercq
# 3                             NaN
# 4                             NaN
# ...

# %% [markdown]
# **DATA** **EXPLORATION**

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
print(f"Netflix Data : {netflix.shape} in rows and cols")
# Out:
# Netflix Data : (8807, 12) in rows and cols

# %%
netflix.describe(include='object')
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
#
#                       cast        country       date_added rating  duration  \
# count                 7982           7976             8797   8803      8804
# unique                7692            748             1767     17       220
# top     David Attenborough  United States  January 1, 2020  TV-MA  1 Season
# freq                    19           2818              109   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# ...

# %% [markdown]
# **COLUMN** **NAMES**

# %%
netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# **NULL VALUES PRESENT**

# %%
netflix.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# **UNIQUE VALUES**

# %%
#netflix['director'].replace(np.nan,'No Director', inplace=True)
#netflix['country'].replace(np.nan,'No Country', inplace=True)
#netflix['cast'].replace(np.nan,'No Cast', inplace=True)
#netflix.isnull().sum()

# %% [markdown]
# **Drop Null Values**

# %%
netflix_copy = netflix.copy()

netflix_copy = netflix_copy.dropna()

netflix_copy.shape
# Out:
# (8790, 15)

# %% [markdown]
# **Duplicate Values**

# %%
print(f"Duplicate values found : {netflix_copy.duplicated().sum()}")
# Out:
# Duplicate values found : 0

# %% [markdown]
# **Rating Types**

# %%
netflix_copy['rating'].value_counts()
# Out:
# TV-MA       3205
# TV-14       2157
# TV-PG        861
# R            799
# PG-13        490
# TV-Y7        333
# TV-Y         306
# PG           287
# TV-G         220
# NR            79
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: rating, dtype: int64

# %% [markdown]
# **Converting Date Time Format**

# %%
netflix_copy['date_added'] = pd.to_datetime(netflix_copy['date_added'])
netflix_copy['day_added'] = netflix_copy['date_added'].dt.day
netflix_copy['year_added'] = netflix_copy['date_added'].dt.year
netflix_copy['month_added']= netflix_copy['date_added'].dt.month
netflix_copy['year_added'].astype(int);
netflix_copy['day_added'].astype(int);
netflix_copy.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                    No Director
# 2                Julien Leclercq
# 3                    No Director
# 4                    No Director
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %% [markdown]
# **Visualization of Data**

# %% [markdown]
# Movies against Tv Shows

# %%
sns.countplot(netflix_copy, x ='type')

plt.xticks(rotation = 45)
plt.xlabel('Content Type')
plt.ylabel('Count')
plt.title('Distribution of Movies and Tv Shows on Netflix')
plt.show()

# %% [markdown]
# **Tv Show Ratings**
